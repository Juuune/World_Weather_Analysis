# %%
import pandas as pd

# %%
# Store the CSV you saved created in part one into a DataFrame.
hotel_df = pd.read_csv("data/WeatherPy_vacation.csv")
hotel_df.head()
# Out:
#    index          City Country  Max Temp Current Description    Lat    Lng  \
# 0      6  Kamariotissa      GR    300.15    scattered clouds  40.48  25.47
# 1     11        Castro      BR    297.01           clear sky -24.79 -50.01
# 2     14      Barcelos      PT    297.59          few clouds  41.54  -8.62
# 3     18          Lata      PT    298.15           clear sky  40.16  -8.33
# 4     25     Tamandare      BR    298.81    scattered clouds  -8.76 -35.10
#
#            Hotel Name
# 0          Niki Beach
# 1      CHACARA BAILLY
# 2      Hotel Do Terço
# 3         Casa Maquia
# 4  Pousada 100 Passos

# %%
df1 = hotel_df.loc[(hotel_df["City"] == "Barcelos")]
df2 = hotel_df.loc[(hotel_df["City"] == 'Sestri Levante')] 
df3 = hotel_df.loc[(hotel_df["City"] == 'Santona')] 
df4 = hotel_df.loc[(hotel_df["City"] == 'Senj')]

# %%
hotel_df.set_index("City")
# Out:
#               index Country  Max Temp Current Description    Lat     Lng  \
# City
# Kamariotissa      6      GR    300.15    scattered clouds  40.48   25.47
# Castro           11      BR    297.01           clear sky -24.79  -50.01
# Barcelos         14      PT    297.59          few clouds  41.54   -8.62
# Lata             18      PT    298.15           clear sky  40.16   -8.33
# Tamandare        25      BR    298.81    scattered clouds  -8.76  -35.10
# ...             ...     ...       ...                 ...    ...     ...
# Wajima          543      JP    300.64           clear sky  37.40  136.90
# Sur             544      OM    302.22       broken clouds  22.57   59.53
# Dobric          545      RS    297.59       broken clouds  44.70   19.58
# Sarangani       549      PH    301.55     overcast clouds   5.40  125.46
# Senj            552      HR    299.15    scattered clouds  44.99   14.91
#
#                         Hotel Name
# City
# Kamariotissa            Niki Beach
# ...

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
raining = to_bool(input("Do you want it to be raining? (yes/no) "))
snowing = to_bool(input("Do you want it to be snowing? (yes/no) "))

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(hotel_df["Max Temp"] <= max_temp) & \
                                       (hotel_df["Max Temp"] >= min_temp) & \
                                       (hotel_df["Rain (inches)"] == raining) & \
                                       (hotel_df["Snow (inches)"] == snowing)]
preferred_cities_df.head(10)

# %%
fig = gmaps.figure()
geneva2zurich_via_montreux = gmaps.directions_layer(
        geneva, zurich, waypoints=[montreux],
        travel_mode='BICYCLING')
fig.add_layer(geneva2zurich_via_montreux)
fig
