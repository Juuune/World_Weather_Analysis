# %% [markdown]
# # Challenge 1. Get the Weather Description and Amount of Precipitation for Each City

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import gmaps
import requests
import pprint as pp
from datetime import datetime

# Import citypy module
from citipy import citipy

# Import the API key.
from config2 import g_key
from config2 import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 596

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial/exclude=current,hourly&appid=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial/exclude=current,hourly&appid=58d2344785c89d71f3ed3a096b8a32e0

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#Loop through all the cities in our list
for i,city in enumerate(cities):

    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create end point URL with each city. 
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city. 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
           
    # Parse the JSON and retrieve data.
    city_weather = requests.get(city_url).json()
    
    # Get the rainfall data
    try: 
        city_rainfall = city_weather["rain"]["1h"]
    except KeyError:
        city_rainfall = 0
        pass
    
    # Get the snowfall data
    try:
        city_snowfall = city_weather["snow"]["1h"]
    except KeyError:
        city_snowfall = 0
        pass
    
    # Run an API request for each weather parameter of the cities.        
    try:
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_des = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_des,
                          "Rain (inches)" : city_rainfall,
                          "Snow (inches)" : city_snowfall,
                          "Country": city_country,
                          "Date": city_date})

      # If an error is experienced, skip the city.
    except:
           print("City not found. Skipping...")
           pass
        
    # Add 1 to the record count 
    record_count += 1 
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lebu
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | scarborough
# Processing Record 4 of Set 1 | songea
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | saskylakh
# Processing Record 7 of Set 1 | kamariotissa
# Processing Record 8 of Set 1 | bolu
# Processing Record 9 of Set 1 | prince rupert
# Processing Record 10 of Set 1 | bambous virieux
# Processing Record 11 of Set 1 | krasnoselkup
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | brae
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 1 | barcelos
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | huacho
# ...

# %%
len(city_data)
# Out:
# 554

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0             Lebu -37.62  -73.65    284.39        79         100        4.76
# 1          Ushuaia -54.80  -68.30    278.15        38          40       10.30
# 2      Scarborough  54.28   -0.40    286.48        87          99        0.45
# 3           Songea -10.68   35.65    295.15        60          20        2.10
# 4            Bluff -46.60  168.33    279.08        80          75        5.95
# 5        Saskylakh  71.92  114.08    284.18        68           2        1.75
# 6     Kamariotissa  40.48   25.47    300.15        54          30        3.10
# 7             Bolu  40.67   31.58    289.41        76          31        1.38
# 8    Prince Rupert  54.32 -130.32    285.15        93          40        2.10
# 9  Bambous Virieux -20.34   57.76    295.15        83          75        5.70
#
#   Current Description  Rain (inches)  Snow (inches) Country  \
# ...

# %%
new_city_order =["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description","Rain (inches)","Snow (inches)"]
city_data_df = city_data_df[new_city_order]

# %%
# Create the output file (CSV).
output_data_file = "data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
